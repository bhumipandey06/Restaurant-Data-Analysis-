# %% [markdown]
# # Restaurant Data Analysis
#
# ## Project Overview
# This project analyzes restaurant data to understand customer preferences, pricing patterns, and rating distributions.
#
# ## Objectives
#
# • Analyze restaurant rating distribution
# • Identify most common cuisines
# • Find cities with most restaurants
# • Explore price range patterns
# • Identify top rated restaurants
#
# ## Tools Used
# - Python
# - Pandas
# - Matplotlib
# - Seaborn

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style("whitegrid")

# %%
df = pd.read_csv("zomato.csv")

# %%
df.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0     restaurant name restaurant type  \
# 0             0           0        #FeelTheROLL     Quick Bites
# 1             1           1          #L-81 Cafe     Quick Bites
# 2             2           2             #refuel            Cafe
# 3             3           3  '@ Biryani Central   Casual Dining
# 4             4           4          '@ The Bbq   Casual Dining
#
#    rate (out of 5)  num of ratings  avg cost (two people) online_order  \
# 0              3.4               7                  200.0           No
# 1              3.9              48                  400.0          Yes
# 2              3.7              37                  400.0          Yes
# 3              2.7             135                  550.0          Yes
# 4              2.8              40                  700.0          Yes
#
#   table booking                                      cuisines type  \
# 0            No                                          Fast Food
# ...

# %%
df.shape
# Out:
# (7105, 12)

# %%
df.columns
# Out:
# Index(['Unnamed: 0.1', 'Unnamed: 0', 'restaurant name', 'restaurant type',
#        'rate (out of 5)', 'num of ratings', 'avg cost (two people)',
#        'online_order', 'table booking', 'cuisines type', 'area',
#        'local address'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7105 entries, 0 to 7104
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Unnamed: 0.1           7105 non-null   int64
#  1   Unnamed: 0             7105 non-null   int64
#  2   restaurant name        7105 non-null   object
#  3   restaurant type        7105 non-null   object
#  4   rate (out of 5)        7037 non-null   float64
#  5   num of ratings         7105 non-null   int64
#  6   avg cost (two people)  7048 non-null   float64
#  7   online_order           7105 non-null   object
#  8   table booking          7105 non-null   object
#  9   cuisines type          7105 non-null   object
#  10  area                   7105 non-null   object
#  11  local address          7105 non-null   object
# dtypes: float64(2), int64(3), object(7)
# memory usage: 666.2+ KB

# %%
df.isnull().sum()
# Out:
# Unnamed: 0.1              0
# Unnamed: 0                0
# restaurant name           0
# restaurant type           0
# rate (out of 5)          68
# num of ratings            0
# avg cost (two people)    57
# online_order              0
# table booking             0
# cuisines type             0
# area                      0
# local address             0
# dtype: int64

# %% [markdown]
# Removing Unnecessary Columns

# %%
df.drop(["Unnamed: 0","Unnamed: 0.1"], axis=1, inplace=True)

# %%
df.columns
# Out:
# Index(['restaurant name', 'restaurant type', 'rate (out of 5)',
#        'num of ratings', 'avg cost (two people)', 'online_order',
#        'table booking', 'cuisines type', 'area', 'local address'],
#       dtype='object')

# %% [markdown]
# Check Missing Values

# %%
df.isnull().sum()
# Out:
# restaurant name           0
# restaurant type           0
# rate (out of 5)          68
# num of ratings            0
# avg cost (two people)    57
# online_order              0
# table booking             0
# cuisines type             0
# area                      0
# local address             0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.shape
# Out:
# (6984, 10)

# %% [markdown]
# Rename Columns

# %%
df.rename(columns={
"restaurant name":"restaurant_name",
"restaurant type":"restaurant_type",
"rate (out of 5)":"rating",
"num of ratings":"num_ratings",
"avg cost (two people)":"avg_cost",
"table booking":"table_booking",
"cuisines type":"cuisine",
"local address":"address"
}, inplace=True)

# %%
df.columns
# Out:
# Index(['restaurant_name', 'restaurant_type', 'rating', 'num_ratings',
#        'avg_cost', 'online_order', 'table_booking', 'cuisine', 'area',
#        'address'],
#       dtype='object')

# %% [markdown]
# Rating Distribution Analysis

# %%
sns.histplot(df["rating"], bins=20)
plt.title("Restaurant Rating Distribution")
plt.xlabel("Rating")
plt.ylabel("Count")
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# Top Areas with Most Restaurants

# %%
df["area"].value_counts().head(10)
df["area"].value_counts().head(10).plot(kind="bar")
plt.title("Top Areas with Most Restaurants")
plt.xlabel("Area")
plt.ylabel("Number of Restaurants")
# Out:
# Text(0, 0.5, 'Number of Restaurants')
